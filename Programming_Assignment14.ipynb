# %% [markdown]
# # Q1

# %%
'''
Question 1:
Define a class with a generator which can iterate the numbers, which are divisible by
7, between a given range 0 and n.
'''
print()

# %%
class gen:
    def __init__(self,n):
        self.n=n
    def generator(self):
        genn = [i for i in range(self.n) if(i%7)==0]
        return genn

# %%
generator1=gen(30)

# %%
generator1.generator()
# Out:
# [0, 7, 14, 21, 28]

# %%
generator1=gen(100)

# %%
generator1.generator()
# Out:
# [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]

# %%
# Here gen is generator which gives the range of values from 0 to n which are divisible by 7

# %% [markdown]
# # Q2

# %%
'''
Question 2:
Write a program to compute the frequency of the words from the input. The output
should output after sorting the key alphanumerically.
Suppose the following input is supplied to the program:
New to Python or choosing between Python 2 and Python 3? Read Python 2 or
Python 3.
Then, the output should be:
2:2
3.:1
3?:1
New:1
Python:5
Read:1
and:1
between:1
choosing:1
or:2
to:1
'''
print()

# %%
l = [i for i in input().split(' ')]
s=set(l)
for i in s:
    print('{} : {}'.format(i,l.count(i)))
# Out:
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3
# 2 : 2
# 3 : 1
# Read : 1
# New : 1
# or : 2
# and : 1
# 3? : 1
# to : 1
# Python : 5
# choosing : 1
# between : 1

# %% [markdown]
# # Q3

# %% [markdown]
# ![14_q3.png](attachment:14_q3.png)

# %%
class Person:
    def getGender(self):
        pass
class Male(Person):
    def getGender(self):
        print('Male')
class Female(Person):
    def getGender(self):
        print('Female')

# %%
ma=Male()
fe=Female()

# %%
ma.getGender()
# Out:
# Male

# %%
fe.getGender()
# Out:
# Female

# %% [markdown]
# # Q4

# %% [markdown]
# ![14_q4.png](attachment:14_q4.png)

# %%
def sentence():
    l1=['I','You']
    l2=['Play','Love']
    l3=['Hockey','Football']
    for i in l1:
        s=''
        s=s+" "+i
        b=s
        for j in l2:
            s=b
            s=s+" "+j
            a=s
            for k in l3:
                s=a
                s=s+" "+k
                print(s)

# %%
sentence()
# Out:
#  I Play Hockey
#  I Play Football
#  I Love Hockey
#  I Love Football
#  You Play Hockey
#  You Play Football
#  You Love Hockey
#  You Love Football

# %% [markdown]
# # Q5

# %% [markdown]
# ![14_q5.png](attachment:14_q5.png)

# %%
import zlib
s='hello world!hello world!hello world!hello world!'
x = bytes(s, 'utf-8')
c=zlib.compress(x)
print(c)
d=zlib.decompress(c)
print(d)
# Out:
# b'x\x9c\xcbH\xcd\xc9\xc9W(\xcf/\xcaIQ\xcc \x82\r\x00\xbd[\x11\xf5'
# b'hello world!hello world!hello world!hello world!'

# %% [markdown]
# # Q6

# %% [markdown]
# ![14_q6.png](attachment:14_q6.png)

# %%
def binary_search(l,i):
    return l.index(i)

# %%
l=[1,2,3,4,5]
binary_search(l,2)
# Out:
# 1

# %%
binary_search(l,4)
# Out:
# 3
