# %% [markdown]
# # Q1

# %% [markdown]
# ![17_Q1.png](attachment:17_Q1.png)

# %%
def evenly_divisible(a,b,c):
    sum=0
    for i in range(a,b+1):
        if(i%c==0):
            sum=sum+i
    return sum

# %%
evenly_divisible(1,10,20)
# Out:
# 0

# %%
evenly_divisible(1,10,2)
# Out:
# 30

# %%
evenly_divisible(1,10,3)
# Out:
# 18

# %% [markdown]
# # Q2

# %% [markdown]
# ![17_q2.png](attachment:17_q2.png)

# %%
def correct_signs(string):
    return eval(string)

# %%
correct_signs('3<7<11')
# Out:
# True

# %%
correct_signs('13>44>33>1')
# Out:
# False

# %%
correct_signs('1<2<6<9>3')
# Out:
# True

# %% [markdown]
# # Q3

# %% [markdown]
# ![17_Q3.png](attachment:17_Q3.png)

# %%
def replace_vowels(string,b):
    v=['a','e','i','o','u']
    s=''
    for i in string:
        if(i in v):
            s=s+b
        else:
            s=s+i
    return s

# %%
replace_vowels('the aardvark','#')
# Out:
# 'th# ##rdv#rk'

# %%
replace_vowels('minnie mouse','?')
# Out:
# 'm?nn?? m??s?'

# %%
replace_vowels('shakespeare','*')
# Out:
# 'sh*k*sp**r*'

# %% [markdown]
# # Q4

# %% [markdown]
# ![17_Q4.png](attachment:17_Q4.png)

# %%
def factorial(n):
    
    if(n==1 or n==0):
        return 1
    else:
        return (n*factorial(n-1))

# %%
factorial(5)
# Out:
# 120

# %%
factorial(3)
# Out:
# 6

# %%
factorial(1)
# Out:
# 1

# %%
factorial(0)
# Out:
# 1

# %% [markdown]
# # Q5

# %% [markdown]
# ![17_Q5.png](attachment:17_Q5.png)

# %%
def hamming_distance(str1,str2):
        c=0
        n=max(len(str1),len(str2))
        for i in range(n):
            if(str1[i]!=str2[i]):
                c+=1
        return c

# %%
hamming_distance('abcde','bcdef')
# Out:
# 5

# %%
hamming_distance('abcde','abcde')
# Out:
# 0

# %%
hamming_distance('strong','strung')
# Out:
# 1
